# %%
import modan_rna3d
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import modan_rna3d
#
# File ~\Documents\GitHub\RNA_Analysis_Public\Geoff_code\modan_rna3d.py:2
#       1 import openpyxl
# ----> 2 import xlsxwriter
#       3 import numpy as np
#       4 import csv
#
# ModuleNotFoundError: No module named 'xlsxwriter'

# %%
pip install xlsxwriter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import modan_rna3d
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import modan_rna3d
#
# File ~\Documents\GitHub\RNA_Analysis_Public\Geoff_code\modan_rna3d.py:445
#     443 detail = sys.argv[file]
#     444 stack = sys.argv[file+1]
# --> 445 sugarrib = sys.argv[file+2]
#     447 #creates the array of all interactions
#     448 basepairs = []
#
# IndexError: list index out of range
