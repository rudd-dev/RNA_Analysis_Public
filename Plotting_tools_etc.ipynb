# %%
import matplotlib.pyplot as plt

# %%
plt.pie([1,2,3])
# Out:
# ([<matplotlib.patches.Wedge at 0x1bf69da06e0>,
# ...
#  [Text(0.9526279361491276, 0.5500000138802306, ''),
#   Text(-0.5500000555209211, 0.9526279121078616, ''),
#   Text(1.311736850028664e-08, -1.0999999999999999, '')])

# %%
list("Hello")
# Out:
# ['H', 'e', 'l', 'l', 'o']
